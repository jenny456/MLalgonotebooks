# %%
import pandas as pd

# %%
df=pd.read_csv('SPECT')

# %%
df.tail(10)
# Out:
#     Class  Attr_1  Attr_2  Attr_3  Attr_4  Attr_5  Attr_6  Attr_7  Attr_8  \
# 257    No       0       0       0       0       0       0       0       0
# 258    No       0       0       0       0       0       0       0       0
# 259    No       0       0       0       0       1       0       0       0
# 260    No       0       0       1       1       0       0       0       1
# 261    No       0       0       0       0       0       0       0       0
# 262    No       0       0       0       0       0       0       0       0
# 263    No       1       1       0       0       0       1       0       0
# 264    No       1       0       1       0       1       0       0       1
# 265    No       1       0       1       0       1       0       0       1
# 266    No       0       0       0       0       0       0       0       0
#
#      Attr_9   ...     Attr_13  Attr_14  Attr_15  Attr_16  Attr_17  Attr_18  \
# 257       0   ...           0        0        0        0        0        0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
number=LabelEncoder()
df['Class']=number.fit_transform(df['Class'].astype('str'))
df.tail(10)
# Out:
#      Class  Attr_1  Attr_2  Attr_3  Attr_4  Attr_5  Attr_6  Attr_7  Attr_8  \
# 257      0       0       0       0       0       0       0       0       0
# 258      0       0       0       0       0       0       0       0       0
# 259      0       0       0       0       0       1       0       0       0
# 260      0       0       0       1       1       0       0       0       1
# 261      0       0       0       0       0       0       0       0       0
# 262      0       0       0       0       0       0       0       0       0
# 263      0       1       1       0       0       0       1       0       0
# 264      0       1       0       1       0       1       0       0       1
# 265      0       1       0       1       0       1       0       0       1
# 266      0       0       0       0       0       0       0       0       0
#
#      Attr_9   ...     Attr_13  Attr_14  Attr_15  Attr_16  Attr_17  Attr_18  \
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
np.random.seed(7)

# %%
y=df.iloc[:,0]
x=df.iloc[:,1:]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1000)

# %%
model=Sequential()
model.add(Dense(5,input_dim=xtrain.shape[1],activation='sigmoid'))
model.add(Dense(5,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(xtrain,ytrain,epochs=100,batch_size=10)
scores=model.evaluate(xtest,ytest)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("The summary:")
model.summary()
# Out:
# Epoch 1/100
# 213/213 [==============================] - 1s 6ms/step - loss: 0.8462 - acc: 0.2254
# Epoch 2/100
# 213/213 [==============================] - 0s 140us/step - loss: 0.7955 - acc: 0.2254
# Epoch 3/100
# 213/213 [==============================] - 0s 131us/step - loss: 0.7513 - acc: 0.2254
# Epoch 4/100
# 213/213 [==============================] - 0s 130us/step - loss: 0.7133 - acc: 0.2582
# Epoch 5/100
# 213/213 [==============================] - 0s 165us/step - loss: 0.6811 - acc: 0.6667
# Epoch 6/100
# 213/213 [==============================] - 0s 113us/step - loss: 0.6546 - acc: 0.7746
# Epoch 7/100
# 213/213 [==============================] - 0s 104us/step - loss: 0.6304 - acc: 0.7746
# Epoch 8/100
# 213/213 [==============================] - 0s 125us/step - loss: 0.6119 - acc: 0.7746
# Epoch 9/100
# 213/213 [==============================] - 0s 136us/step - loss: 0.5953 - acc: 0.7746
# Epoch 10/100
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest=RandomForestClassifier(n_estimators=100,random_state=0)
forest.fit(xtrain,ytrain)
print('accuracy on the training subset : {:.3f}' .format(forest.score(xtrain,ytrain)))
print('accuracy on the test subset : {:.3f}' .format(forest.score(xtest,ytest)))
# Out:
# accuracy on the training subset : 0.925
# accuracy on the test subset : 0.944
